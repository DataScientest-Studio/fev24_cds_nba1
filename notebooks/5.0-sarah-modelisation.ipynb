# %%
# Import libraries
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_selection import SelectKBest, chi2, VarianceThreshold, f_classif, mutual_info_classif
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/processed/all_shots-v4.csv", index_col=0)
pd.set_option('display.max_columns', 500)

#df.info()

# %%
df.drop(['Y Location', 'Away Team', 'Season Type', 'Year',
         'GAME_ID', 'EVENTNUM', 'PLAYER1_NAME', 'PLAYER1_TEAM_ABBREVIATION', 'OPPONENT_TEAM',
         'hook_shot', 'layup_shot', 'dunk_shot', 'jump_shot', 'free_throw', ], axis = 1, inplace=True)

# %%
df.columns
# Out:
# Index(['Shot Distance', 'X Location', 'Shot Zone Basic_Above the Break 3',
#        'Shot Zone Basic_Backcourt', 'Shot Zone Basic_In The Paint (Non-RA)',
#        'Shot Zone Basic_Left Corner 3', 'Shot Zone Basic_Mid-Range',
#        'Shot Zone Basic_Restricted Area', 'Shot Zone Basic_Right Corner 3',
#        'Shot Zone Area_Back Court(BC)', 'Shot Zone Area_Center(C)',
#        'Shot Zone Area_Left Side Center(LC)', 'Shot Zone Area_Left Side(L)',
#        'Shot Zone Area_Right Side Center(RC)', 'Shot Zone Area_Right Side(R)',
#        'Shot Zone Range_16-24 ft.', 'Shot Zone Range_24+ ft.',
#        'Shot Zone Range_8-16 ft.', 'Shot Zone Range_Back Court Shot',
#        'Shot Zone Range_Less Than 8 ft.', 'target', 'PERIOD', 'at_home',
#        'PREVIOUS_OFF_REBOUND', 'PREVIOUS_DEF_REBOUND', 'PREVIOUS_OFF_TURNOVER',
#        'PREVIOUS_OFF_MISSED', 'PREVIOUS_EVENTMSGTYPE', '3PT',
#        'DETAILLED_SHOT_TYPE', 'minutes_left', 'seconds_left', 'Age', 'TS%',
#        'PTM', 'ASTM', 'ORBM', 'STLM', 'BLKM', 'TOVM', 'USG%', 'FG%', '2P%',
#        '3P%', 'FT%', 'PTS', 'year_start', 'year_end', 'height', 'weight', 'C',
#        'PF', 'PG', 'PG-SG', 'SF', 'SF-SG', 'SG', 'SG-PG', 'E_DEF_RATING',
#        'E_OFF_RATING'],
#       dtype='object')

# %%
df = pd.get_dummies(df)

# %%
df.corr()['target'].abs().sort_values(ascending=False)[:15]
# Out:
# target                                  1.000000
# DETAILLED_SHOT_TYPE_JUMP SHOT           0.318227
# DETAILLED_SHOT_TYPE_FREE THROW          0.268635
# Shot Zone Area_Center(C)                0.234337
# 3PT                                     0.169855
# Shot Zone Range_8-16 ft.                0.167854
# Shot Zone Range_24+ ft.                 0.166267
# Shot Zone Basic_Above the Break 3       0.157543
# PREVIOUS_OFF_MISSED                     0.132595
# Shot Distance                           0.132153
# Shot Zone Range_16-24 ft.               0.120179
# PREVIOUS_EVENTMSGTYPE_FOUL              0.118361
# Shot Zone Area_Left Side Center(LC)     0.107099
# Shot Zone Basic_Mid-Range               0.106453
# Shot Zone Area_Right Side Center(RC)    0.106183
# Name: target, dtype: float64

# %% [markdown]
# ## Séparation des données

# %%
# prepare data for modeling   
X = df.drop('target', axis = 1)
y = df.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, stratify=y, shuffle=True)

# %% [markdown]
# ## Standardisation et réduction de dimension

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

df_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
df_scaled['target'] = y_train

# réduction de dimensions
sel_var = VarianceThreshold(0.001)
X_train_scaled = sel_var.fit_transform(X_train_scaled, y_train)
X_test_scaled = sel_var.transform(X_test_scaled)

# réduction de dimensions
sel_k_best = SelectKBest(f_classif)
sel_k_best.fit(X_train_scaled, y_train)
X_train_kbst = sel_k_best.transform(X_train_scaled)
X_test_kbst = sel_k_best.transform(X_test_scaled)

# Affichage des variables sélectionnées
# kbst = pd.DataFrame(sel_k_best.get_support(), index=X_train.columns)
# kbst["score"]=sel_k_best.scores_
# kbst.sort_values("score", ascending=False)

# %%
pca = PCA()
pca.fit(X_train_scaled)

pca = PCA(0.95)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

print("Composantes Principales retenues : ", pca.n_components_)

plt.figure()
plt.xlim(0,100)
plt.xlabel('Nombre de composantes')
plt.ylabel('Part de variance expliquée')
plt.axhline(y = 0.9, color ='r', linestyle = '--')
plt.plot(pca.explained_variance_ratio_.cumsum());

# %% [markdown]
# ## Arbre de décision

# %%
dt_clf = DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_split=2)

dt_clf.fit(X_train, y_train)
y_pred = dt_clf.predict(X_test)
print('Train accuracy with DT:', dt_clf.score(X_train, y_train))
print('Test accuracy with DT:', dt_clf.score(X_test, y_test))
pd.crosstab(y_test, y_pred, rownames=["Classes réelles"], colnames=["Classes prédites"])
# Out:
# Train accuracy with DT: 0.6911309591534873
# Test accuracy with DT: 0.6832859255888042
# Classes prédites      0      1
# Classes réelles
# 0                 25061  13274
# 1                 14562  34993

# %%
plt.figure(figsize=(25,6))
plot_tree(dt_clf,feature_names=X_train.columns, filled=True, proportion=True, rounded=True, fontsize=8, max_depth=4)
plt.show()

# %%
import optuna

def dtree_objective(trial):
    
    md = trial.suggest_int('max_depth', 2, 64)
    mi = trial.suggest_int('min_samples_split', 2, 32)
    cr = trial.suggest_categorical("criterion", ["entropy", "gini", "log_loss"])
    minleaf = trial.suggest_int('min_samples_leaf', 1, 32)
    
    clf =  DecisionTreeClassifier(max_depth=md, min_samples_leaf=minleaf, criterion=cr, min_samples_split=mi)

    scores = cross_val_score(clf, X_train, y_train, cv=5, scoring='accuracy')
    
    return scores.mean()
    
dtree_study = optuna.create_study(direction='maximize')
dtree_study.optimize(dtree_objective, n_trials=20)

print("Number of finished trials: ", len(dtree_study.trials))
print("Best trial:")
trial = dtree_study.best_trial

print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-08-13 12:19:24,236] A new study created in memory with name: no-name-e7e4eba8-8171-4b67-bbfc-31c8576f5341
# [I 2024-08-13 12:19:36,645] Trial 0 finished with value: 0.6704118784844691 and parameters: {'max_depth': 3, 'min_samples_split': 2, 'criterion': 'log_loss', 'min_samples_leaf': 30}. Best is trial 0 with value: 0.6704118784844691.
# [I 2024-08-13 12:20:20,634] Trial 1 finished with value: 0.6569916941631585 and parameters: {'max_depth': 19, 'min_samples_split': 10, 'criterion': 'log_loss', 'min_samples_leaf': 14}. Best is trial 0 with value: 0.6704118784844691.
# [I 2024-08-13 12:21:03,903] Trial 2 finished with value: 0.6414182500853339 and parameters: {'max_depth': 42, 'min_samples_split': 29, 'criterion': 'gini', 'min_samples_leaf': 13}. Best is trial 0 with value: 0.6704118784844691.
# [I 2024-08-13 12:21:39,639] Trial 3 finished with value: 0.6718853111844351 and parameters: {'max_depth': 15, 'min_samples_split': 10, 'criterion': 'log_loss', 'min_samples_leaf': 9}. Best is trial 3 with value: 0.6718853111844351.
# [I 2024-08-13 12:22:22,389] Trial 4 finished with value: 0.6488764364546593 and parameters: {'max_depth': 43, 'min_samples_split': 26, 'criterion': 'log_loss', 'min_samples_leaf': 19}. Best is trial 3 with value: 0.6718853111844351.
# [I 2024-08-13 12:23:09,751] Trial 5 finished with value: 0.6334281488223916 and parameters: {'max_depth': 43, 'min_samples_split': 31, 'criterion': 'entropy', 'min_samples_leaf': 6}. Best is trial 3 with value: 0.6718853111844351.
# [I 2024-08-13 12:23:56,194] Trial 6 finished with value: 0.6413556718625555 and parameters: {'max_depth': 49, 'min_samples_split': 7, 'criterion': 'log_loss', 'min_samples_leaf': 14}. Best is trial 3 with value: 0.6718853111844351.
# [I 2024-08-13 12:24:43,185] Trial 7 finished with value: 0.632111161679372 and parameters: {'max_depth': 52, 'min_samples_split': 25, 'criterion': 'gini', 'min_samples_leaf': 5}. Best is trial 3 with value: 0.6718853111844351.
# [I 2024-08-13 12:25:04,439] Trial 8 finished with value: 0.6810843099328706 and parameters: {'max_depth': 7, 'min_samples_split': 28, 'criterion': 'gini', 'min_samples_leaf': 32}. Best is trial 8 with value: 0.6810843099328706.
# [I 2024-08-13 12:25:43,681] Trial 9 finished with value: 0.6571083172147002 and parameters: {'max_depth': 36, 'min_samples_split': 27, 'criterion': 'gini', 'min_samples_leaf': 28}. Best is trial 8 with value: 0.6810843099328706.
# [I 2024-08-13 12:26:25,184] Trial 10 finished with value: 0.6523722835362384 and parameters: {'max_depth': 64, 'min_samples_split': 19, 'criterion': 'entropy', 'min_samples_leaf': 23}. Best is trial 8 with value: 0.6810843099328706.
# [I 2024-08-13 12:26:58,009] Trial 11 finished with value: 0.6739759927181705 and parameters: {'max_depth': 14, 'min_samples_split': 16, 'criterion': 'gini', 'min_samples_leaf': 2}. Best is trial 8 with value: 0.6810843099328706.
# [I 2024-08-13 12:27:06,274] Trial 12 finished with value: 0.6704118784844691 and parameters: {'max_depth': 2, 'min_samples_split': 17, 'criterion': 'gini', 'min_samples_leaf': 1}. Best is trial 8 with value: 0.6810843099328706.
# [I 2024-08-13 12:27:43,578] Trial 13 finished with value: 0.6590141085447719 and parameters: {'max_depth': 20, 'min_samples_split': 19, 'criterion': 'gini', 'min_samples_leaf': 23}. Best is trial 8 with value: 0.6810843099328706.
# [I 2024-08-13 12:28:10,865] Trial 14 finished with value: 0.683320059164865 and parameters: {'max_depth': 11, 'min_samples_split': 15, 'criterion': 'gini', 'min_samples_leaf': 32}. Best is trial 14 with value: 0.683320059164865.
# [I 2024-08-13 12:28:48,401] Trial 15 finished with value: 0.6606070087609511 and parameters: {'max_depth': 27, 'min_samples_split': 22, 'criterion': 'gini', 'min_samples_leaf': 32}. Best is trial 14 with value: 0.683320059164865.
# [I 2024-08-13 12:29:12,531] Trial 16 finished with value: 0.6833627261349414 and parameters: {'max_depth': 9, 'min_samples_split': 13, 'criterion': 'gini', 'min_samples_leaf': 26}. Best is trial 16 with value: 0.6833627261349414.
# [I 2024-08-13 12:29:53,371] Trial 17 finished with value: 0.6561554215496643 and parameters: {'max_depth': 26, 'min_samples_split': 13, 'criterion': 'entropy', 'min_samples_leaf': 26}. Best is trial 16 with value: 0.6833627261349414.
# [I 2024-08-13 12:30:22,304] Trial 18 finished with value: 0.6796706109910116 and parameters: {'max_depth': 12, 'min_samples_split': 5, 'criterion': 'gini', 'min_samples_leaf': 20}. Best is trial 16 with value: 0.6833627261349414.
# [I 2024-08-13 12:31:00,831] Trial 19 finished with value: 0.6564256456934804 and parameters: {'max_depth': 27, 'min_samples_split': 13, 'criterion': 'gini', 'min_samples_leaf': 26}. Best is trial 16 with value: 0.6833627261349414.
# Number of finished trials:  20
# Best trial:
#   Value: 0.6833627261349414
#   Params:
#     max_depth: 9
#     min_samples_split: 13
#     criterion: gini
#     min_samples_leaf: 26

# %% [markdown]
# # Régression Logistique

# %%
scaler = StandardScaler()

lr = LogisticRegression(solver='liblinear', max_iter=1000)

pipeline = Pipeline(steps = [('normalization', scaler),
                             ('logistic_regression', lr)])

pipeline.fit(X_train, y_train)

print("Validation Mean F1 Score: ", cross_val_score(
    pipeline, X_train, y_train, cv=5, scoring='f1_macro').mean())

print("Validation Mean Accuracy: ", cross_val_score(
    pipeline, X_train, y_train, cv=5, scoring='accuracy').mean())
# Out:
# Validation Mean F1 Score:  0.6699910556799529
# Validation Mean Accuracy:  0.6761178746159973

# %%
n = X_train.shape[1]

pca = PCA(n_components=2)

scaler = StandardScaler()

pipeline_pca = Pipeline(steps = [('normalization', scaler),
                                 ('pca', pca)])

X_new = pipeline_pca.fit_transform(X_train)

coeff = pca.components_.transpose()

xs = X_new[:, 0]
ys = X_new[:, 1]
scalex = 1.0/(xs.max() - xs.min())
scaley = 1.0/(ys.max() - ys.min())


principalDf = pd.DataFrame({'PC1': xs*scalex, 'PC2': ys * scaley})

y_train_pred = pipeline.predict(X_train)
finalDF = pd.concat([principalDf, pd.Series(
    y_train_pred, name='income')], axis=1)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
fig.set_figheight(15)
fig.set_figwidth(15)

ax.set_facecolor('xkcd:salmon')

sns.scatterplot(x='PC1', y='PC2', hue='income', data=finalDF, alpha=0.5, ax=ax)
for i in range(n):
    plt.arrow(0, 0, coeff[i, 0]*1.5, coeff[i, 1]*1.5,
              color='k', alpha=0.5, head_width=0.01, )
    plt.text(coeff[i, 0]*1.5, coeff[i, 1] * 1.5, X_train.columns[i], color='k')

plt.xlim(-0.6, 0.8)
plt.ylim(-0.8, 0.8)

# %%
from skater.core.local_interpretation.lime.lime_tabular import LimeTabularExplainer

# Nous reconstruisons le même modèle mais avec des numpy arrays pour éviter les problème avec LIME du au nomns des features

xgc_np = xgb.XGBClassifier(n_estimators=1000, max_depth=6, base_score=0.5,
                           objective='binary:logistic', eval_metric='logloss', use_label_encoder=False)
xgc_np.fit(X_train.values, y_train)


exp = LimeTabularExplainer(X_test.values, feature_names=list(X_test.columns), 
                           class_names=['Tir raté', 'Tir réussi'])

# %% [markdown]
# ## Random Forest

# %%
clf = RandomForestClassifier(n_jobs = -1)
clf.fit(X_train_pca, y_train)
clf.score(X_test_pca, y_test)
# Out:
# 0.6735464785527364

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb
import optuna


train = xgb.DMatrix(data=X_train, label=y_train)
test = xgb.DMatrix(data=X_test, label=y_test)


def objective(trial):
    param = {
        "verbosity": 0,
        "objective": "binary:logistic",
        # use exact for small dataset.
        "tree_method": "exact",
        # defines booster, gblinear for linear functions.
        "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
        # L2 regularization weight.
        "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
        # L1 regularization weight.
        "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        # sampling ratio for training data.
        "subsample": trial.suggest_float("subsample", 0.2, 1.0),
        # sampling according to each tree.
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
    }

    if param["booster"] in ["gbtree", "dart"]:
        # maximum depth of the tree, signifies complexity of the tree.
        param["max_depth"] = trial.suggest_int("max_depth", 3, 9, step=2)
        # minimum child weight, larger the term more conservative the tree.
        param["min_child_weight"] = trial.suggest_int("min_child_weight", 2, 10)
        param["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
        # defines how selective algorithm is.
        param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
        param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])

    if param["booster"] == "dart":
        param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
        param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)

    bst = xgb.train(param, train)
    preds = bst.predict(test)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(y_test, pred_labels)
    return accuracy

# 3. Create a study object and optimize the objective function.
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

print("Number of finished trials: ", len(study.trials))
print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-08-13 11:38:48,134] A new study created in memory with name: no-name-d55795ea-04c8-4787-a431-b1051b267d03
# [I 2024-08-13 11:39:17,094] Trial 0 finished with value: 0.6174308795084765 and parameters: {'booster': 'gbtree', 'lambda': 0.4711964398765692, 'alpha': 0.0017178653097182672, 'subsample': 0.5040356031783092, 'colsample_bytree': 0.9400073674547469, 'max_depth': 9, 'min_child_weight': 7, 'eta': 0.030497250942591588, 'gamma': 0.002484742893580052, 'grow_policy': 'depthwise'}. Best is trial 0 with value: 0.6174308795084765.
# [I 2024-08-13 11:39:30,723] Trial 1 finished with value: 0.5638297872340425 and parameters: {'booster': 'gbtree', 'lambda': 2.9242471073215743e-05, 'alpha': 2.9274634068751614e-07, 'subsample': 0.6033805237546999, 'colsample_bytree': 0.4972086179481197, 'max_depth': 7, 'min_child_weight': 10, 'eta': 0.0026469873895545084, 'gamma': 2.160451814547953e-07, 'grow_policy': 'depthwise'}. Best is trial 0 with value: 0.6174308795084765.
# [I 2024-08-13 11:39:33,035] Trial 2 finished with value: 0.6183297303447491 and parameters: {'booster': 'gblinear', 'lambda': 0.4661273553203621, 'alpha': 0.0013891029037586384, 'subsample': 0.6021824808477377, 'colsample_bytree': 0.41722744710151805}. Best is trial 2 with value: 0.6183297303447491.
# [I 2024-08-13 11:39:34,809] Trial 3 finished with value: 0.581363067470702 and parameters: {'booster': 'gblinear', 'lambda': 2.733547358610587e-06, 'alpha': 0.11178189332955925, 'subsample': 0.9136254714077268, 'colsample_bytree': 0.33857181663602925}. Best is trial 2 with value: 0.6183297303447491.
# [I 2024-08-13 11:39:43,416] Trial 4 finished with value: 0.6775514848105586 and parameters: {'booster': 'dart', 'lambda': 0.002909860870437287, 'alpha': 0.0004001521452874244, 'subsample': 0.9236067286328005, 'colsample_bytree': 0.38525746121069304, 'max_depth': 5, 'min_child_weight': 6, 'eta': 0.37006993825348106, 'gamma': 5.244624544231411e-08, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 7.856008934619288e-07, 'skip_drop': 0.593607395626861}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:39:50,581] Trial 5 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 0.0036420359609623957, 'alpha': 1.659909907018923e-07, 'subsample': 0.3087166987286636, 'colsample_bytree': 0.7491083576498585, 'max_depth': 3, 'min_child_weight': 9, 'eta': 1.3651190335287177e-06, 'gamma': 0.9131378340631722, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.2164738928560075e-07, 'skip_drop': 3.136340635207855e-07}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:40:00,145] Trial 6 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 1.412124316020687e-06, 'alpha': 0.005807204537063949, 'subsample': 0.5074714507888192, 'colsample_bytree': 0.44888738101726616, 'max_depth': 5, 'min_child_weight': 3, 'eta': 1.5307090166294624e-07, 'gamma': 3.7318391967919277e-07, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 3.387480434025069e-06, 'skip_drop': 5.984877437121742e-07}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:40:03,511] Trial 7 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 1.1654140927219053e-05, 'alpha': 0.0016161550188316812, 'subsample': 0.22242185582385138, 'colsample_bytree': 0.42659118818886577, 'max_depth': 3, 'min_child_weight': 5, 'eta': 4.011598370295183e-08, 'gamma': 0.0002747362793705902, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 0.854906147738565, 'skip_drop': 1.0585624622877554e-07}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:40:16,818] Trial 8 finished with value: 0.5638297872340425 and parameters: {'booster': 'gbtree', 'lambda': 0.017423891449613385, 'alpha': 7.466257080253432e-05, 'subsample': 0.7031810479879346, 'colsample_bytree': 0.5904021150401482, 'max_depth': 7, 'min_child_weight': 6, 'eta': 0.00024315865730357818, 'gamma': 1.305084801806178e-05, 'grow_policy': 'lossguide'}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:40:27,247] Trial 9 finished with value: 0.5695642280122881 and parameters: {'booster': 'gbtree', 'lambda': 0.003410986351722118, 'alpha': 0.0033065862770797374, 'subsample': 0.9921337735871882, 'colsample_bytree': 0.4833075365327326, 'max_depth': 7, 'min_child_weight': 9, 'eta': 0.02481386369315108, 'gamma': 0.003700935420403813, 'grow_policy': 'depthwise'}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:40:36,577] Trial 10 finished with value: 0.6751848902036637 and parameters: {'booster': 'dart', 'lambda': 1.591499307940918e-08, 'alpha': 6.58499802399724e-06, 'subsample': 0.8381087799670114, 'colsample_bytree': 0.22618760930159496, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.4558055571780953, 'gamma': 3.728919972389039e-08, 'grow_policy': 'lossguide', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 0.0013060373580020715, 'skip_drop': 0.37144556250617455}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:40:43,649] Trial 11 finished with value: 0.6764592103766072 and parameters: {'booster': 'dart', 'lambda': 1.1297315014475043e-08, 'alpha': 7.340042122779198e-06, 'subsample': 0.8423606524501965, 'colsample_bytree': 0.21074325421468892, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.9996576682556733, 'gamma': 1.6206204894854626e-08, 'grow_policy': 'lossguide', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 0.005002457399850488, 'skip_drop': 0.3103552180289245}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:40:50,826] Trial 12 finished with value: 0.6757082717032654 and parameters: {'booster': 'dart', 'lambda': 2.3010613694553407e-08, 'alpha': 1.0259855216547544e-05, 'subsample': 0.7860378793111088, 'colsample_bytree': 0.21485047930316817, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.8847128368997652, 'gamma': 1.0647417468173978e-08, 'grow_policy': 'lossguide', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 0.0011864109922977986, 'skip_drop': 0.6571624481078375}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:40:58,333] Trial 13 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 0.000383570883270746, 'alpha': 1.8507285441937614e-08, 'subsample': 0.9649035117757773, 'colsample_bytree': 0.30707030245212674, 'max_depth': 5, 'min_child_weight': 7, 'eta': 2.5868349105050495e-05, 'gamma': 2.547879542045616e-06, 'grow_policy': 'lossguide', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 1.516479064709577e-08, 'skip_drop': 0.0039752209548124}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:41:07,761] Trial 14 finished with value: 0.6556263511207191 and parameters: {'booster': 'dart', 'lambda': 1.765436181853231e-07, 'alpha': 2.3910056071518495e-05, 'subsample': 0.8217377781148568, 'colsample_bytree': 0.7199884859247209, 'max_depth': 3, 'min_child_weight': 2, 'eta': 0.04113262877060456, 'gamma': 7.290345688839451e-07, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.9481681596607065e-05, 'skip_drop': 0.002040048222947763}. Best is trial 4 with value: 0.6775514848105586.
# [I 2024-08-13 11:41:23,315] Trial 15 finished with value: 0.6811013767209011 and parameters: {'booster': 'dart', 'lambda': 0.000488956448504525, 'alpha': 1.5600038461801866e-06, 'subsample': 0.7330212064743182, 'colsample_bytree': 0.31827090861335083, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.9137027681417171, 'gamma': 3.243864445823381e-08, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 0.07120011375183781, 'skip_drop': 0.014051395910173261}. Best is trial 15 with value: 0.6811013767209011.
# [I 2024-08-13 11:41:25,450] Trial 16 finished with value: 0.5638297872340425 and parameters: {'booster': 'gblinear', 'lambda': 0.00025894756967471673, 'alpha': 0.7128102275476633, 'subsample': 0.7141193995172065, 'colsample_bytree': 0.5950079920335404}. Best is trial 15 with value: 0.6811013767209011.
# [I 2024-08-13 11:41:39,215] Trial 17 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 0.0048228781976575085, 'alpha': 6.185491431862168e-07, 'subsample': 0.7368587927695933, 'colsample_bytree': 0.36272278108368267, 'max_depth': 9, 'min_child_weight': 5, 'eta': 0.0012821835471291513, 'gamma': 1.9214299813681686e-05, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 0.6140694740712266, 'skip_drop': 0.005585563737638726}. Best is trial 15 with value: 0.6811013767209011.
# [I 2024-08-13 11:42:01,693] Trial 18 finished with value: 0.6774718397997497 and parameters: {'booster': 'dart', 'lambda': 0.04269734486333919, 'alpha': 0.00022274751536249237, 'subsample': 0.8906482845046352, 'colsample_bytree': 0.699856100035708, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.07589215845948247, 'gamma': 1.0834972601999547e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.0007863165420339e-06, 'skip_drop': 4.994237117244864e-05}. Best is trial 15 with value: 0.6811013767209011.
# [I 2024-08-13 11:42:04,312] Trial 19 finished with value: 0.669803163044715 and parameters: {'booster': 'gblinear', 'lambda': 0.0005144110170033702, 'alpha': 1.353356643366791e-06, 'subsample': 0.46256508681481795, 'colsample_bytree': 0.31309680066888357}. Best is trial 15 with value: 0.6811013767209011.
# [I 2024-08-13 11:42:24,889] Trial 20 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 6.742102210897046e-05, 'alpha': 4.018821981434835e-08, 'subsample': 0.9066396536468663, 'colsample_bytree': 0.9952858547056624, 'max_depth': 7, 'min_child_weight': 7, 'eta': 2.0843916824223837e-05, 'gamma': 3.926104889982235e-06, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 9.961270291381406e-05, 'skip_drop': 0.02952971729845551}. Best is trial 15 with value: 0.6811013767209011.
# [I 2024-08-13 11:42:47,312] Trial 21 finished with value: 0.6848902036636705 and parameters: {'booster': 'dart', 'lambda': 0.054139903881992454, 'alpha': 0.0002192198046669897, 'subsample': 0.8991020574686053, 'colsample_bytree': 0.7124892803051163, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.14404511358784397, 'gamma': 2.3397575498550342e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.266830414704116e-06, 'skip_drop': 4.625417191430333e-05}. Best is trial 21 with value: 0.6848902036636705.
# [I 2024-08-13 11:43:15,703] Trial 22 finished with value: 0.6859483445215611 and parameters: {'booster': 'dart', 'lambda': 0.08206964341694024, 'alpha': 0.00020672099400898187, 'subsample': 0.6565237414557263, 'colsample_bytree': 0.8487759276195711, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.15769080168010208, 'gamma': 9.216604563773339e-08, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 5.006650278606881e-07, 'skip_drop': 4.420350575968825e-05}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:43:39,525] Trial 23 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 0.12661066500693782, 'alpha': 6.487250688725976e-05, 'subsample': 0.6698186438601302, 'colsample_bytree': 0.8462267589412926, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.0029286613049023546, 'gamma': 6.696770250368488e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.05459931114597783, 'skip_drop': 2.509103482309676e-05}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:44:03,981] Trial 24 finished with value: 0.6848902036636705 and parameters: {'booster': 'dart', 'lambda': 0.06457134914367488, 'alpha': 1.9439878636885277e-06, 'subsample': 0.6419353239847339, 'colsample_bytree': 0.8256423990651929, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.11601227485290498, 'gamma': 8.12572635151444e-05, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 8.055446029999704e-08, 'skip_drop': 5.734714035486957e-06}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:44:28,149] Trial 25 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 0.9758322439383998, 'alpha': 0.028923248467246105, 'subsample': 0.3760439127013377, 'colsample_bytree': 0.8232353741400387, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.00892503938523182, 'gamma': 0.0001410732117824237, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.1375695940903986e-08, 'skip_drop': 4.313408800001245e-06}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:44:55,837] Trial 26 finished with value: 0.6845374900443737 and parameters: {'booster': 'dart', 'lambda': 0.07239849802781685, 'alpha': 0.0002968092696590149, 'subsample': 0.6451211408595426, 'colsample_bytree': 0.8596909640414226, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.12258808879376189, 'gamma': 0.38337919461098185, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.8789836620415377e-07, 'skip_drop': 0.0004893972648244499}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:45:12,087] Trial 27 finished with value: 0.5638297872340425 and parameters: {'booster': 'gbtree', 'lambda': 0.02415510968709257, 'alpha': 0.021580075789339168, 'subsample': 0.5432307926144679, 'colsample_bytree': 0.7826241224211788, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.00025280043466157785, 'gamma': 0.047521135490727416, 'grow_policy': 'depthwise'}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:45:15,245] Trial 28 finished with value: 0.6383547616338605 and parameters: {'booster': 'gblinear', 'lambda': 0.177128175195679, 'alpha': 4.251958031671749e-05, 'subsample': 0.3940055136934575, 'colsample_bytree': 0.6645601335739819}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:45:45,039] Trial 29 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 0.0112519697218643, 'alpha': 3.386501213293813e-06, 'subsample': 0.5242990450448423, 'colsample_bytree': 0.9503107162916369, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.009632343011454537, 'gamma': 0.0010935763514785014, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 9.323330983390327e-06, 'skip_drop': 3.531549780589089e-06}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:46:04,492] Trial 30 finished with value: 0.6822619183069746 and parameters: {'booster': 'gbtree', 'lambda': 0.25950893648944323, 'alpha': 0.000984998478983792, 'subsample': 0.7820951628282741, 'colsample_bytree': 0.90040341106205, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.1341455607621934, 'gamma': 3.071521615377477e-05, 'grow_policy': 'depthwise'}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:46:33,117] Trial 31 finished with value: 0.6848902036636705 and parameters: {'booster': 'dart', 'lambda': 0.06423843091854775, 'alpha': 0.000285555222688018, 'subsample': 0.6425142348443723, 'colsample_bytree': 0.875944164997529, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.12911186664265126, 'gamma': 0.04235043944518757, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.6798901902645768e-07, 'skip_drop': 0.00042612763390453227}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:46:59,111] Trial 32 finished with value: 0.6850267379679145 and parameters: {'booster': 'dart', 'lambda': 0.051408786808585426, 'alpha': 0.0001400238264111452, 'subsample': 0.574444138535154, 'colsample_bytree': 0.7939155630906253, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.17217880080081865, 'gamma': 0.03705090120195451, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 7.758898454046043e-08, 'skip_drop': 0.000204630883377902}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:47:20,416] Trial 33 finished with value: 0.5667652747752873 and parameters: {'booster': 'dart', 'lambda': 0.9876596862129735, 'alpha': 2.4311582023254023e-05, 'subsample': 0.5742172689894192, 'colsample_bytree': 0.8074489960573011, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.015825347815028132, 'gamma': 0.012150625241425872, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 5.4469356385730655e-08, 'skip_drop': 9.645822989540301e-06}. Best is trial 22 with value: 0.6859483445215611.
# [I 2024-08-13 11:47:44,585] Trial 34 finished with value: 0.685959722380248 and parameters: {'booster': 'dart', 'lambda': 0.013709307334856896, 'alpha': 0.000769455374612891, 'subsample': 0.5713110640514684, 'colsample_bytree': 0.7563642709865491, 'max_depth': 9, 'min_child_weight': 2, 'eta': 0.24028978422671407, 'gamma': 3.547225104745727e-06, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 9.072207995469952e-07, 'skip_drop': 0.0001069547301584303}. Best is trial 34 with value: 0.685959722380248.
# [I 2024-08-13 11:48:07,207] Trial 35 finished with value: 0.6290249175105245 and parameters: {'booster': 'dart', 'lambda': 0.008037924298116913, 'alpha': 0.009131305247380221, 'subsample': 0.4462943796266846, 'colsample_bytree': 0.6367178833907041, 'max_depth': 9, 'min_child_weight': 2, 'eta': 0.034012531179231205, 'gamma': 3.885926776857343e-06, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.073612164535815e-06, 'skip_drop': 0.0001962583588721769}. Best is trial 34 with value: 0.685959722380248.
# [I 2024-08-13 11:48:09,690] Trial 36 finished with value: 0.6684036864262146 and parameters: {'booster': 'gblinear', 'lambda': 0.0010272702629666446, 'alpha': 0.00014237311681616633, 'subsample': 0.6091347520854826, 'colsample_bytree': 0.7558688759191244}. Best is trial 34 with value: 0.685959722380248.
# [I 2024-08-13 11:48:37,820] Trial 37 finished with value: 0.6864375924451018 and parameters: {'booster': 'dart', 'lambda': 0.2944545686385192, 'alpha': 0.0007407566537411825, 'subsample': 0.5766218331240859, 'colsample_bytree': 0.9190832414217771, 'max_depth': 9, 'min_child_weight': 2, 'eta': 0.18933879307911025, 'gamma': 1.2445363285625764e-06, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 3.32312193233679e-05, 'skip_drop': 4.123907571803158e-05}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:48:57,441] Trial 38 finished with value: 0.5638297872340425 and parameters: {'booster': 'gbtree', 'lambda': 0.3913602401130939, 'alpha': 0.0007830206009224582, 'subsample': 0.5775396831407245, 'colsample_bytree': 0.9185993459729118, 'max_depth': 7, 'min_child_weight': 2, 'eta': 0.002962509091459073, 'gamma': 1.453796356065882e-06, 'grow_policy': 'depthwise'}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:49:24,340] Trial 39 finished with value: 0.6843782000227557 and parameters: {'booster': 'dart', 'lambda': 0.0014301391500583089, 'alpha': 0.0027696181365005255, 'subsample': 0.48964388694596905, 'colsample_bytree': 0.9677349677496575, 'max_depth': 9, 'min_child_weight': 2, 'eta': 0.3673926257814073, 'gamma': 8.622143354562617e-06, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 6.178850830934069e-05, 'skip_drop': 1.5584883921244673e-08}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:49:42,782] Trial 40 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 0.02108897730888098, 'alpha': 0.00070133080203891, 'subsample': 0.546814567497331, 'colsample_bytree': 0.898570179114391, 'max_depth': 7, 'min_child_weight': 3, 'eta': 0.0007882664568951361, 'gamma': 1.1557523566159036e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.03804194935527e-05, 'skip_drop': 0.00015834934895685897}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:50:03,250] Trial 41 finished with value: 0.6842302878598248 and parameters: {'booster': 'dart', 'lambda': 0.14675444837418483, 'alpha': 0.0001248257925456362, 'subsample': 0.437832521017248, 'colsample_bytree': 0.7714291825700653, 'max_depth': 9, 'min_child_weight': 2, 'eta': 0.2928583423949527, 'gamma': 1.617840749069237e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 4.838660784196324e-07, 'skip_drop': 4.111998443963961e-05}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:50:20,255] Trial 42 finished with value: 0.6414609170554102 and parameters: {'booster': 'dart', 'lambda': 0.35211378112211195, 'alpha': 0.009771956117482192, 'subsample': 0.6089117745728637, 'colsample_bytree': 0.560272090229072, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.03776079795362754, 'gamma': 4.6965231629316854e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 3.7795428755254753e-06, 'skip_drop': 0.0010647458026442434}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:50:38,158] Trial 43 finished with value: 0.6846171350551826 and parameters: {'booster': 'dart', 'lambda': 0.033621407644861295, 'alpha': 0.0004574443648135969, 'subsample': 0.6880737612292351, 'colsample_bytree': 0.725259372194609, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.2846868620753761, 'gamma': 1.245916789872606e-06, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.9613029465220515e-06, 'skip_drop': 2.1356578193982157e-05}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:50:54,870] Trial 44 finished with value: 0.5638297872340425 and parameters: {'booster': 'dart', 'lambda': 0.00930291004541624, 'alpha': 0.0029121409851218917, 'subsample': 0.3228332746256694, 'colsample_bytree': 0.6452488723289186, 'max_depth': 9, 'min_child_weight': 6, 'eta': 0.007078724637808078, 'gamma': 1.8565142654649193e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 3.476136040610332e-07, 'skip_drop': 0.00011513862683676996}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:51:13,373] Trial 45 finished with value: 0.67678916827853 and parameters: {'booster': 'dart', 'lambda': 0.11564605876001462, 'alpha': 0.0015184854763866395, 'subsample': 0.4950558216664339, 'colsample_bytree': 0.6890927209190791, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.07053262912766285, 'gamma': 6.362720270427822e-08, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 3.845729682598763e-08, 'skip_drop': 1.5198398323988357e-06}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:51:29,468] Trial 46 finished with value: 0.6843440664466948 and parameters: {'booster': 'dart', 'lambda': 0.002050010274810382, 'alpha': 2.208239925897535e-05, 'subsample': 0.571171555493313, 'colsample_bytree': 0.7947396744877573, 'max_depth': 7, 'min_child_weight': 2, 'eta': 0.258854208503519, 'gamma': 0.0007931525545179413, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 2.3101785948226908e-05, 'skip_drop': 7.471214818583895e-05}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:51:45,989] Trial 47 finished with value: 0.5638297872340425 and parameters: {'booster': 'gbtree', 'lambda': 1.1207690465919535e-05, 'alpha': 0.00013532669144171222, 'subsample': 0.40760158786672457, 'colsample_bytree': 0.7367646688826289, 'max_depth': 9, 'min_child_weight': 10, 'eta': 4.446202261385016e-07, 'gamma': 6.38831912556328e-06, 'grow_policy': 'depthwise'}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:51:47,592] Trial 48 finished with value: 0.5981909204687678 and parameters: {'booster': 'gblinear', 'lambda': 0.5297348959708872, 'alpha': 0.038626379358781895, 'subsample': 0.7810257962937708, 'colsample_bytree': 0.8681578884228611}. Best is trial 37 with value: 0.6864375924451018.
# [I 2024-08-13 11:52:07,392] Trial 49 finished with value: 0.5738423028785983 and parameters: {'booster': 'dart', 'lambda': 0.0044987786567765595, 'alpha': 4.0259136482331325e-05, 'subsample': 0.8789046371992496, 'colsample_bytree': 0.8319538155352999, 'max_depth': 9, 'min_child_weight': 5, 'eta': 0.01836939131566627, 'gamma': 3.0934578246062827e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 3.6675442423140025e-06, 'skip_drop': 1.5401010611192576e-05}. Best is trial 37 with value: 0.6864375924451018.
# Number of finished trials:  50
# Best trial:
#   Value: 0.6864375924451018
#   Params:
#     booster: dart
#     lambda: 0.2944545686385192
#     alpha: 0.0007407566537411825
#     subsample: 0.5766218331240859
#     colsample_bytree: 0.9190832414217771
#     max_depth: 9
#     min_child_weight: 2
#     eta: 0.18933879307911025
#     gamma: 1.2445363285625764e-06
#     grow_policy: depthwise
#     sample_type: weighted
#     normalize_type: tree
#     rate_drop: 3.32312193233679e-05
#     skip_drop: 4.123907571803158e-05

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
import optuna

def knn_objective(trial):
    
    neighbors = trial.suggest_int('n_neighbors', 2, 20)
    weights = trial.suggest_categorical("weights", ["uniform", "distance"])
    algorithm = trial.suggest_categorical("algorithm", ["ball_tree", "kd_tree", "brute"])
    leaf_size = trial.suggest_int('leaf_size', 30, 40)
    metric = trial.suggest_categorical("metric", ["euclidean", "manhattan", "minkowski"])

    clf =  KNeighborsClassifier(n_jobs=-1, n_neighbors=neighbors, weights=weights, algorithm=algorithm, leaf_size=leaf_size, metric=metric)

    scores = cross_val_score(clf, X_train_scaled, y_train, cv=3, scoring='accuracy')
    
    return scores.mean()
    
dtree_study = optuna.create_study(direction='maximize')
dtree_study.optimize(knn_objective, n_trials=1)

print("Number of finished trials: ", len(dtree_study.trials))
print("Best trial:")
trial = dtree_study.best_trial

print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-08-13 15:34:16,117] A new study created in memory with name: no-name-da1f7c52-5d20-4084-b2b1-6ccc36fe1023
# [I 2024-08-13 16:40:56,925] Trial 0 finished with value: 0.6140488100689655 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'algorithm': 'brute', 'leaf_size': 36, 'metric': 'manhattan'}. Best is trial 0 with value: 0.6140488100689655.
# Number of finished trials:  1
# Best trial:
#   Value: 0.6140488100689655
#   Params:
#     n_neighbors: 2
#     weights: distance
#     algorithm: brute
#     leaf_size: 36
#     metric: manhattan

# %% [markdown]
# ## Voting Classifier

# %%
from sklearn.ensemble import VotingClassifier, StackingClassifier, RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC


clf1 = KNeighborsClassifier(n_neighbors = 3)
clf2 = RandomForestClassifier(random_state = 123)
clf3 = LogisticRegression(max_iter = 1000)
clf4 = SVC(C=.1)

vclf = VotingClassifier(estimators = [('knn', clf1), ('rf', clf2), ('lr', clf3), ('svc', clf4)], voting = 'hard')


params = {'knn__n_neighbors': [5, 9],
          'rf__n_estimators': [20, 100, 200],
          'svm__C': [0.01, 0.1, 1],
        'estimators': [[('knn', clf1), ('rf', clf2), ('lr', clf3), ('svm', clf4)]] 
          }

grid = GridSearchCV(estimator=vclf, param_grid=params, cv=5)
grid = grid.fit(X_train, y_train)
print(grid.best_params_)
# Out:
# c:\Users\Sarah\anaconda3\envs\nba_env\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Sarah\anaconda3\envs\nba_env\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Sarah\anaconda3\envs\nba_env\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Sarah\anaconda3\envs\nba_env\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
